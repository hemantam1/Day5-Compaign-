# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:Admin%40123@localhost/amazon_ads_db')
query = "SELECT * FROM bid_optimization_metrics"
master_df = pd.read_sql(query, con=engine)

# %%
master_df
# Out:
#             date                           campaign_id  \
# 0     2023-02-13  6c788904-66fb-4701-9a90-349d6c66c447
# 1     2023-02-14  6c788904-66fb-4701-9a90-349d6c66c447
# 2     2023-02-15  6c788904-66fb-4701-9a90-349d6c66c447
# 3     2023-02-16  6c788904-66fb-4701-9a90-349d6c66c447
# 4     2023-02-17  6c788904-66fb-4701-9a90-349d6c66c447
# ...          ...                                   ...
# 5470  2026-02-07  d38c1acb-a4b8-49a1-8c62-9867a812f5f6
# 5471  2026-02-08  d38c1acb-a4b8-49a1-8c62-9867a812f5f6
# 5472  2026-02-09  d38c1acb-a4b8-49a1-8c62-9867a812f5f6
# 5473  2026-02-10  d38c1acb-a4b8-49a1-8c62-9867a812f5f6
# 5474  2026-02-11  d38c1acb-a4b8-49a1-8c62-9867a812f5f6
#
#                                 product_id  is_weekend  is_salary_day  \
# 0     a9d07467-76cd-4dbc-b245-f003297b5b32           0              0
# 1     f6b9f302-0352-45cb-bd0d-6c74f2466b9f           0              0
# 2     b6bcc51c-940f-4700-b7cd-7de524573575           0              0
# ...

# %%
master_df.describe()
# Out:
#         is_weekend  is_salary_day  daily_budget  current_bid  organic_rank  \
# count  5475.000000    5475.000000   5475.000000  5475.000000   5475.000000
# mean      0.284932       0.376256   1897.932104     3.502150     25.083836
# std       0.451423       0.484490    635.460107     1.157378     14.202722
# min       0.000000       0.000000    800.046023     1.500000      1.000000
# 25%       0.000000       0.000000   1345.935376     2.490000     13.000000
# 50%       0.000000       0.000000   1886.186295     3.490000     25.000000
# 75%       1.000000       1.000000   2448.572588     4.530000     37.000000
# max       1.000000       1.000000   2999.528632     5.500000     49.000000
#
#        competitor_pressure       clicks        spend        sales  \
# count          5475.000000  5475.000000  5475.000000  5475.000000
# mean              1.004292   588.191963  1662.101512  1056.009005
# std               0.288932   376.340373   563.175889   753.908240
# ...

# %%
master_df.columns
# Out:
# Index(['date', 'campaign_id', 'product_id', 'is_weekend', 'is_salary_day',
#        'daily_budget', 'current_bid', 'organic_rank', 'competitor_pressure',
#        'clicks', 'spend', 'sales', 'orders', 'cvr', 'acos', 'optimal_bid',
#        'sales_lag_1', 'acos_lag_1', 'spend_lag_1', 'bid_budget_ratio',
#        'roas_lag_1', 'ad_intensity_index', 'avg_cvr_7d', 'avg_acos_7d',
#        'spend_velocity'],
#       dtype='object')

# %%
master_df['sales_lag_1'] = master_df['sales'].shift(1)

master_df['avg_sales_7d'] = (
    master_df['sales']
    .rolling(window=7)
    .mean()
    .shift(1)
)

# %%
master_df['sales_lag_1'] = master_df.groupby('campaign_id')['sales'].shift(1)

# %%
master_df.drop(['campaign_id','product_id','clicks','spend','sales','orders','cvr','acos','spend_velocity'],axis=1,inplace=True)

# %%
master_df.columns
# Out:
# Index(['date', 'is_weekend', 'is_salary_day', 'daily_budget', 'current_bid',
#        'organic_rank', 'competitor_pressure', 'optimal_bid', 'sales_lag_1',
#        'acos_lag_1', 'spend_lag_1', 'bid_budget_ratio', 'roas_lag_1',
#        'ad_intensity_index', 'avg_cvr_7d', 'avg_acos_7d', 'avg_sales_7d'],
#       dtype='object')

# %%
master_df
# Out:
#             date  is_weekend  is_salary_day  daily_budget  current_bid  \
# 0     2023-02-13           0              0   2277.251916         2.03
# 1     2023-02-14           0              0   2632.841034         4.62
# 2     2023-02-15           0              0   2496.014420         3.68
# 3     2023-02-16           0              0   2417.168342         2.89
# 4     2023-02-17           0              0   2031.756725         1.70
# ...          ...         ...            ...           ...          ...
# 5470  2026-02-07           1              0   2142.494253         1.91
# 5471  2026-02-08           1              0   1487.560387         3.84
# 5472  2026-02-09           0              0   2210.276991         2.99
# 5473  2026-02-10           0              0   1527.134320         1.74
# 5474  2026-02-11           0              0   2898.875881         5.37
#
#       organic_rank  competitor_pressure  optimal_bid  sales_lag_1  acos_lag_1  \
# ...
